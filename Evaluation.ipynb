# %% [markdown]
# # Оценка 1: accuracy по выделению упоминаний с категориями

# %%
from collections import defaultdict

gold_test_path = "dev_aspects.txt"
pred_test_path = "dev_pred_aspects.txt"

# %%
gold_aspect_cats = {}
with open(gold_test_path) as fg:
    for line in fg:
        line = line.rstrip('\r\n').split('\t')
        if line[0] not in gold_aspect_cats:
            gold_aspect_cats[line[0]] = {"starts":[], "ends":[], "cats":[], "sents":[]}
        gold_aspect_cats[line[0]]["starts"].append(int(line[3]))
        gold_aspect_cats[line[0]]["ends"].append(int(line[4]))
        gold_aspect_cats[line[0]]["cats"].append(line[1])
        gold_aspect_cats[line[0]]["sents"].append(line[5])

# %%
full_match, partial_match, full_cat_match, partial_cat_match = 0, 0, 0, 0
total = 0
fully_matched_pairs = []
partially_matched_pairs = []
with open(pred_test_path) as fp:
    for line in fp:    
        total += 1
        line = line.rstrip('\r\n').split('\t')
        start, end = int(line[3]), int(line[4])
        category = line[1]
        doc_gold_aspect_cats = gold_aspect_cats[line[0]]
        
        if start in doc_gold_aspect_cats["starts"]:
            i = doc_gold_aspect_cats["starts"].index(start)
            if doc_gold_aspect_cats["ends"][i] == end:
                full_match += 1
                if doc_gold_aspect_cats["cats"][i] == category:
                    full_cat_match += 1
                else:
                    partial_cat_match += 1
                fully_matched_pairs.append((
                    [doc_gold_aspect_cats["starts"][i], 
                     doc_gold_aspect_cats["ends"][i], 
                     doc_gold_aspect_cats["cats"][i],
                     doc_gold_aspect_cats["sents"][i]],
                    line
                ))
                continue
    
        for s_pos in doc_gold_aspect_cats["starts"]:
            if start <= s_pos:
                i = doc_gold_aspect_cats["starts"].index(s_pos)
                if doc_gold_aspect_cats["ends"][i] == end:
                    partial_match += 1
                    partially_matched_pairs.append((
                        [doc_gold_aspect_cats["starts"][i], 
                         doc_gold_aspect_cats["ends"][i], 
                         doc_gold_aspect_cats["cats"][i],
                         doc_gold_aspect_cats["sents"][i]],
                        line
                    ))
                    if doc_gold_aspect_cats["cats"][i] == category:
                        partial_cat_match += 1
                    continue
                matched = False
                for e_pos in doc_gold_aspect_cats["ends"][i:]:
                    if s_pos <= end <= e_pos:
                        partial_match += 1
                        partially_matched_pairs.append(
                            (
                                [
                                    doc_gold_aspect_cats["starts"][i], 
                                    doc_gold_aspect_cats["ends"][i], 
                                    doc_gold_aspect_cats["cats"][i],
                                    doc_gold_aspect_cats["sents"][i]
                                ],
                                line
                            )
                        )
                        if doc_gold_aspect_cats["cats"][i] == category:
                            partial_cat_match += 1
                        matched = True
                        break
                if matched:
                    break
            if start > s_pos:
                i = doc_gold_aspect_cats["starts"].index(s_pos)
                if start < doc_gold_aspect_cats["ends"][i] <= end:
                    partial_match += 1
                    partially_matched_pairs.append(
                        (
                            [
                                doc_gold_aspect_cats["starts"][i], 
                                doc_gold_aspect_cats["ends"][i], 
                                doc_gold_aspect_cats["cats"][i],
                                doc_gold_aspect_cats["sents"][i]
                            ],
                            line
                        )
                    )
                    if doc_gold_aspect_cats["cats"][i] == category:
                        partial_cat_match += 1
                    break

# %%
gold_size = sum([len(gold_aspect_cats[x]["cats"]) for x in gold_aspect_cats])

# %%
print(f"""
Full match precision: {full_match / total}
Full match recall: {full_match / gold_size}
Partial match ratio in pred: {(full_match + partial_match)  / total}
Full category accuracy: {full_cat_match / total}
Partial category accuracy: {(full_cat_match + partial_cat_match) / total}
""")
# Out:
# Full match precision: 0.48
# Full match recall: 0.7159663865546219
# Partial match ratio in pred: 0.6197183098591549
# Full category accuracy: 0.46422535211267607
# Partial category accuracy: 0.6033802816901408

# %% [markdown]
# # Оценка 2: accuracy по тональности упоминаний

# %%
def sentiment_accuracy(matches):
    matched_sentiment = 0.
    for pair in matches:
        *_, gold_s = pair[0]
        *_, pred_s = pair[1]
        if gold_s == pred_s:
            matched_sentiment += 1
    print(f"Mention sentiment accuracy: {matched_sentiment / len(matches)}")

# %%
partially_matched_pairs
# Out:
# [([188, 205, 'Service', 'neutral'],
#   ['13823', 'Interior', 'столу', '200', '205', 'positive']),
#  ([208, 217, 'Service', 'neutral'],
#   ['13823', 'Food', 'меню', '213', '217', 'positive']),
#  ([254, 267, 'Service', 'neutral'],
#   ['13823', 'Service', 'заказ', '262', '267', 'positive']),
#  ([495, 506, 'Food', 'positive'],
#   ['13823', 'Food', 'ланч', '502', '506', 'negative']),
#  ([680, 692, 'Service', 'positive'],
#   ['13823', 'Service', 'качество обслуживания', '671', '692', 'positive']),
#  ([407, 422, 'Service', 'positive'],
#   ['1427', 'Service', 'человек', '415', '422', 'positive']),
#  ([589, 600, 'Service', 'positive'],
#   ['1427', 'Food', 'меню', '596', '600', 'positive']),
#  ([1035, 1051, 'Service', 'positive'],
#   ['1427', 'Service', 'заказ', '1046', '1051', 'positive']),
#  ([1052, 1067, 'Service', 'positive'],
#   ['1427', 'Service', 'человек', '1060', '1067', 'positive']),
#  ([1109, 1121, 'Interior', 'positive'],
#   ['1427', 'Interior', 'музыка', '1115', '1121', 'positive']),
#  ([1139, 1144, 'Whole', 'positive'],
#   ['1427', 'Whole', 'вечер прошел', '1139', '1151', 'positive']),
#  ([1209, 1226, 'Service', 'positive'],
#   ['1427', 'Service', 'человеку', '1218', '1226', 'positive']),
#  ([27, 44, 'Service', 'neutral'],
#   ['16714', 'Interior', 'столик', '38', '44', 'positive']),
#  ([136, 174, 'Food', 'neutral'],
#   ['16714', 'Food', 'шашлык', '136', '142', 'positive']),
#  ([199, 211, 'Food', 'neutral'],
#   ['16714', 'Food', 'салат', '199', '204', 'positive']),
#  ([234, 254, 'Service', 'negative'],
#   ['34710', 'Service', 'отношение', '234', '243', 'positive']),
#  ([234, 254, 'Service', 'negative'],
#   ['34710', 'Service', 'официантов', '244', '254', 'positive']),
#  ([362, 366, 'Service', 'negative'],
#   ['34710', 'Service', 'дали меню', '362', '371', 'positive']),
#  ([539, 552, 'Service', 'neutral'],
#   ['34710', 'Service', 'заказ', '547', '552', 'positive']),
#  ([131, 145, 'Whole', 'positive'],
#   ['33798', 'Whole', 'вечер', '140', '145', 'positive']),
#  ([229, 257, 'Food', 'positive'],
#   ['33798', 'Food', 'итальянская кухни', '240', '257', 'positive']),
#  ([229, 257, 'Food', 'positive'],
#   ['33798', 'Food', 'кухни', '252', '257', 'positive']),
#  ([325, 339, 'Food', 'positive'],
#   ['33798', 'Food', 'блюда', '325', '330', 'positive']),
#  ([899, 911, 'Interior', 'neutral'],
#   ['2073', 'Interior', 'музыка', '905', '911', 'positive']),
#  ([230, 252, 'Service', 'positive'],
#   ['1434', 'Service', 'персонал', '244', '252', 'positive']),
#  ([326, 348, 'Food', 'neutral'],
#   ['1434', 'Food', 'кухней', '342', '348', 'positive']),
#  ([626, 665, 'Food', 'neutral'],
#   ['1434', 'Food', 'салат', '626', '631', 'positive']),
#  ([704, 719, 'Food', 'neutral'],
#   ['1434', 'Food', 'десерт', '713', '719', 'positive']),
#  ([172, 198, 'Food', 'positive'],
#   ['22386', 'Food', 'рыбой', '193', '198', 'positive']),
#  ([218, 235, 'Food', 'positive'],
#   ['22386', 'Food', 'шашлык', '218', '224', 'positive']),
#  ([218, 235, 'Food', 'positive'],
#   ['22386', 'Food', 'свинины', '228', '235', 'positive']),
#  ([237, 267, 'Food', 'positive'],
#   ['22386', 'Food', 'свинину', '237', '244', 'positive']),
#  ([237, 267, 'Food', 'positive'],
#   ['22386', 'Food', 'грибами', '260', '267', 'positive']),
#  ([19, 44, 'Whole', 'neutral'],
#   ['32442', 'Whole', 'ресторане', '19', '28', 'positive']),
#  ([88, 117, 'Whole', 'positive'],
#   ['32442', 'Service', 'сотрудникам', '88', '99', 'positive']),
#  ([88, 117, 'Whole', 'positive'],
#   ['32442', 'Whole', 'заведения', '108', '117', 'positive']),
#  ([180, 196, 'Service', 'positive'],
#   ['32442', 'Interior', 'танцев', '190', '196', 'positive']),
#  ([277, 293, 'Interior', 'positive'],
#   ['32442', 'Interior', 'оформлением', '277', '288', 'positive']),
#  ([277, 293, 'Interior', 'positive'],
#   ['32442', 'Interior', 'зала', '289', '293', 'positive']),
#  ([438, 448, 'Food', 'positive'],
#   ['32442', 'Food', 'блюд', '444', '448', 'positive']),
#  ([383, 410, 'Food', 'positive'],
#   ['15423', 'Food', 'стейки', '383', '389', 'positive']),
#  ([69, 83, 'Service', 'neutral'],
#   ['13100', 'Interior', 'столик', '77', '83', 'positive']),
#  ([186, 201, 'Service', 'positive'],
#   ['13100', 'Service', 'девушка', '186', '193', 'positive']),
#  ([186, 201, 'Service', 'positive'],
#   ['13100', 'Service', 'хостесс', '194', '201', 'positive']),
#  ([253, 268, 'Service', 'neutral'],
#   ['13100', 'Service', 'человек', '261', '268', 'positive']),
#  ([423, 445, 'Food', 'positive'],
#   ['13100', 'Food', 'хачапури', '423', '431', 'positive']),
#  ([456, 468, 'Food', 'negative'],
#   ['13100', 'Food', 'пицца', '463', '468', 'neutral']),
#  ([473, 489, 'Food', 'neutral'],
#   ['13100', 'Food', 'блюда', '473', '478', 'positive']),
#  ([824, 838, 'Service', 'positive'],
#   ['13100', 'Service', 'Официант', '824', '832', 'positive']),
#  ([99, 124, 'Whole', 'neutral'],
#   ['35635', 'Whole', 'ресторан', '99', '107', 'positive']),
#  ([499, 529, 'Food', 'negative'],
#   ['2107', 'Food', 'овощи', '499', '504', 'positive']),
#  ([124, 138, 'Service', 'neutral'],
#   ['7824', 'Interior', 'столик', '132', '138', 'positive']),
#  ([391, 404, 'Food', 'negative'],
#   ['7824', 'Food', 'цезарь', '398', '404', 'neutral']),
#  ([468, 483, 'Food', 'both'],
#   ['7824', 'Food', 'салат', '468', '473', 'positive']),
#  ([688, 704, 'Food', 'positive'],
#   ['7824', 'Food', 'торт', '688', '692', 'positive']),
#  ([129, 146, 'Service', 'positive'],
#   ['11421', 'Service', 'приносили', '129', '138', 'negative']),
#  ([182, 194, 'Food', 'positive'],
#   ['11421', 'Food', 'выбор', '182', '187', 'both']),
#  ([182, 194, 'Food', 'positive'],
#   ['11421', 'Food', 'меню', '190', '194', 'positive']),
#  ([246, 263, 'Food', 'positive'],
#   ['11421', 'Food', 'разнообразия', '246', '258', 'positive']),
#  ([246, 263, 'Food', 'positive'],
#   ['11421', 'Food', 'блюд', '259', '263', 'positive']),
#  ([222, 231, 'Whole', 'positive'],
#   ['36126', 'Whole', 'впечатлением от посещения', '206', '231', 'positive']),
#  ([376, 392, 'Interior', 'positive'],
#   ['36126', 'Interior', 'зале', '388', '392', 'positive']),
#  ([419, 436, 'Interior', 'positive'],
#   ['36126', 'Interior', 'стола', '431', '436', 'positive']),
#  ([30, 45, 'Whole', 'neutral'],
#   ['13186', 'Whole', 'ресторане', '30', '39', 'positive']),
#  ([80, 98, 'Service', 'positive'],
#   ['13186', 'Service', 'предложила', '80', '90', 'positive']),
#  ([80, 98, 'Service', 'positive'],
#   ['13186', 'Interior', 'столики', '91', '98', 'positive']),
#  ([290, 304, 'Food', 'neutral'],
#   ['13186', 'Food', 'вина', '300', '304', 'positive']),
#  ([330, 367, 'Food', 'neutral'],
#   ['13186', 'Food', 'салат', '330', '335', 'positive']),
#  ([430, 454, 'Service', 'positive'],
#   ['13186', 'Service', 'комплимент', '430', '440', 'positive']),
#  ([430, 454, 'Service', 'positive'],
#   ['13186', 'Service', 'шеф-повара', '444', '454', 'positive']),
#  ([567, 582, 'Service', 'negative'],
#   ['13186', 'Service', 'ждала', '567', '572', 'negative']),
#  ([356, 360, 'Food', 'neutral'],
#   ['9721', 'Food', 'выборе блюд', '349', '360', 'negative']),
#  ([508, 526, 'Food', 'positive'],
#   ['9721', 'Food', 'грибами', '519', '526', 'positive']),
#  ([564, 585, 'Whole', 'positive'],
#   ['9721', 'Whole', 'ресторане', '564', '573', 'positive']),
#  ([720, 734, 'Food', 'positive'],
#   ['9721', 'Food', 'большой выбор', '712', '725', 'positive']),
#  ([720, 734, 'Food', 'positive'],
#   ['9721', 'Food', 'алкоголя', '726', '734', 'neutral']),
#  ([767, 782, 'Food', 'positive'],
#   ['9721', 'Food', 'пива', '778', '782', 'positive']),
#  ([883, 903, 'Whole', 'positive'],
#   ['9721', 'Whole', 'Ресторан', '883', '891', 'positive']),
#  ([515, 528, 'Service', 'positive'],
#   ['28083', 'Service', 'девушка', '515', '522', 'positive']),
#  ([75, 93, 'Service', 'neutral'],
#   ['30744', 'Service', 'заказывали', '75', '85', 'neutral']),
#  ([101, 116, 'Service', 'negative'],
#   ['30744', 'Service', 'заказ', '101', '106', 'positive']),
#  ([101, 116, 'Service', 'negative'],
#   ['30744', 'Service', 'приносили', '107', '116', 'negative']),
#  ([349, 370, 'Service', 'positive'],
#   ['3976', 'Service', 'заказ', '365', '370', 'positive']),
#  ([524, 537, 'Food', 'neutral'],
#   ['3976', 'Food', 'блюдо', '532', '537', 'positive']),
#  ([901, 922, 'Interior', 'positive'],
#   ['3976', 'Interior', 'программа', '913', '922', 'positive']),
#  ([284, 298, 'Food', 'positive'],
#   ['27040', 'Food', 'закуски', '284', '291', 'positive']),
#  ([349, 365, 'Food', 'positive'],
#   ['33591', 'Food', 'хачапури', '349', '357', 'positive']),
#  ([349, 365, 'Food', 'positive'],
#   ['33591', 'Food', 'сыром', '360', '365', 'positive']),
#  ([161, 169, 'Interior', 'positive'],
#   ['28258', 'Interior', 'Интерьер ресторана', '161', '179', 'positive']),
#  ([600, 624, 'Food', 'positive'],
#   ['28258', 'Food', 'грибов', '618', '624', 'positive']),
#  ([741, 750, 'Food', 'neutral'],
#   ['28258', 'Food', 'мясо', '741', '745', 'positive']),
#  ([741, 750, 'Food', 'neutral'],
#   ['28258', 'Food', 'утки', '746', '750', 'negative']),
#  ([791, 808, 'Food', 'positive'],
#   ['28258', 'Food', 'салат', '791', '796', 'positive']),
#  ([791, 808, 'Food', 'positive'],
#   ['28258', 'Food', 'говядиной', '799', '808', 'positive']),
#  ([134, 157, 'Service', 'positive'],
#   ['19503', 'Service', 'администратор', '134', '147', 'positive']),
#  ([270, 286, 'Service', 'positive'],
#   ['19503', 'Service', 'девушка', '270', '277', 'positive']),
#  ([270, 286, 'Service', 'positive'],
#   ['19503', 'Service', 'официант', '278', '286', 'positive']),
#  ([383, 388, 'Food', 'positive'],
#   ['19503', 'Food', 'качестве блюда', '374', '388', 'positive']),
#  ([406, 428, 'Service', 'positive'],
#   ['19503', 'Service', 'персонал', '420', '428', 'positive']),
#  ([98, 118, 'Whole', 'positive'],
#   ['37391', 'Food', 'Пицца', '113', '118', 'neutral']),
#  ([186, 198, 'Food', 'positive'],
#   ['37391', 'Food', 'вина', '194', '198', 'positive']),
#  ([465, 482, 'Food', 'positive'],
#   ['37391', 'Food', 'десерт', '465', '471', 'positive']),
#  ([312, 336, 'Food', 'positive'],
#   ['14568', 'Food', 'судака', '312', '318', 'neutral']),
#  ([312, 336, 'Food', 'positive'],
#   ['14568', 'Food', 'рисом', '331', '336', 'negative']),
#  ([370, 382, 'Food', 'positive'],
#   ['14568', 'Food', 'кофе', '370', '374', 'neutral']),
#  ([432, 449, 'Food', 'positive'],
#   ['14568', 'Food', 'салатов', '442', '449', 'positive']),
#  ([211, 228, 'Food', 'positive'],
#   ['34402', 'Food', 'кухни', '223', '228', 'positive']),
#  ([627, 637, 'Food', 'positive'],
#   ['34402', 'Food', 'выбор', '627', '632', 'both']),
#  ([627, 637, 'Food', 'positive'],
#   ['34402', 'Food', 'вина', '633', '637', 'positive']),
#  ([424, 435, 'Service', 'positive'],
#   ['33524', 'Whole', 'дадут', '424', '429', 'both']),
#  ([424, 435, 'Service', 'positive'],
#   ['33524', 'Service', 'совет', '430', '435', 'positive']),
#  ([473, 485, 'Food', 'neutral'],
#   ['33524', 'Food', 'блюда', '480', '485', 'positive']),
#  ([221, 244, 'Service', 'positive'],
#   ['27375', 'Service', 'администратор', '221', '234', 'positive']),
#  ([221, 244, 'Service', 'positive'],
#   ['27375', 'Whole', 'ресторана', '235', '244', 'positive']),
#  ([353, 373, 'Service', 'positive'],
#   ['27375', 'Service', 'отношение', '353', '362', 'positive']),
#  ([353, 373, 'Service', 'positive'],
#   ['27375', 'Service', 'клиентам', '365', '373', 'negative']),
#  ([630, 650, 'Service', 'negative'],
#   ['31071', 'Service', 'девушка', '630', '637', 'positive']),
#  ([630, 650, 'Service', 'negative'],
#   ['31071', 'Interior', 'гардероба', '641', '650', 'positive']),
#  ([952, 957, 'Food', 'positive'],
#   ['31071', 'Food', 'блюда из меню', '952', '965', 'negative']),
#  ([970, 993, 'Food', 'neutral'],
#   ['31071', 'Food', 'Вино', '970', '974', 'positive']),
#  ([173, 186, 'Food', 'positive'],
#   ['25960', 'Food', 'блюд', '182', '186', 'positive']),
#  ([455, 467, 'Food', 'positive'],
#   ['25960', 'Food', 'еды', '464', '467', 'positive']),
#  ([148, 162, 'Food', 'neutral'],
#   ['9837', 'Food', 'блюдо', '157', '162', 'positive']),
#  ([200, 206, 'Food', 'positive'],
#   ['9837', 'Food', 'размер порций', '193', '206', 'positive']),
#  ([292, 302, 'Interior', 'positive'],
#   ['9837', 'Interior', 'зал', '299', '302', 'positive']),
#  ([71, 95, 'Service', 'positive'],
#   ['27841', 'Service', 'персоналом', '85', '95', 'positive']),
#  ([264, 268, 'Food', 'negative'],
#   ['27841', 'Food', 'Выбор пива', '258', '268', 'positive']),
#  ([573, 591, 'Service', 'positive'],
#   ['27841', 'Service', 'девушка', '573', '580', 'positive']),
#  ([573, 591, 'Service', 'positive'],
#   ['27841', 'Service', 'официантка', '581', '591', 'positive']),
#  ([172, 194, 'Food', 'positive'],
#   ['18780', 'Food', 'блюд', '172', '176', 'positive']),
#  ([172, 194, 'Food', 'positive'],
#   ['18780', 'Food', 'европейской кухни', '177', '194', 'positive']),
#  ([172, 194, 'Food', 'positive'],
#   ['18780', 'Food', 'кухни', '189', '194', 'positive']),
#  ([371, 385, 'Service', 'neutral'],
#   ['18780', 'Service', 'заказа', '371', '377', 'positive']),
#  ([371, 385, 'Service', 'neutral'],
#   ['18780', 'Interior', 'столика', '378', '385', 'positive']),
#  ([502, 510, 'Price', 'neutral'],
#   ['18780', 'Price', 'ценам', '505', '510', 'positive']),
#  ([581, 597, 'Food', 'neutral'],
#   ['18780', 'Food', 'напитки', '590', '597', 'neutral']),
#  ([612, 633, 'Price', 'neutral'],
#   ['18780', 'Service', 'человека', '625', '633', 'positive']),
#  ([803, 806, 'Food', 'positive'],
#   ['18780', 'Food', 'качество еды', '794', '806', 'positive']),
#  ([300, 314, 'Food', 'positive'],
#   ['10798', 'Food', 'кухня', '309', '314', 'positive']),
#  ([368, 385, 'Food', 'positive'],
#   ['10798', 'Food', 'кухня', '380', '385', 'positive']),
#  ([502, 516, 'Service', 'positive'],
#   ['10798', 'Service', 'принесли', '502', '510', 'positive']),
#  ([502, 516, 'Service', 'positive'],
#   ['10798', 'Service', 'заказ', '511', '516', 'positive']),
#  ([331, 347, 'Food', 'positive'],
#   ['12131', 'Food', 'чаем', '331', '335', 'neutral']),
#  ([331, 347, 'Food', 'positive'],
#   ['12131', 'Food', 'пирожными', '338', '347', 'neutral']),
#  ([639, 657, 'Whole', 'positive'],
#   ['12131', 'Whole', 'впечатления', '646', '657', 'positive']),
#  ([767, 787, 'Food', 'positive'],
#   ['26152', 'Food', 'хачапури', '767', '775', 'positive']),
#  ([827, 842, 'Food', 'positive'],
#   ['26152', 'Food', 'Салат', '827', '832', 'positive']),
#  ([901, 930, 'Food', 'positive'],
#   ['26152', 'Food', 'Салат', '901', '906', 'positive']),
#  ([901, 930, 'Food', 'positive'],
#   ['26152', 'Food', 'курицей', '923', '930', 'positive']),
#  ([375, 388, 'Food', 'positive'],
#   ['28112', 'Food', 'мяса', '384', '388', 'positive']),
#  ([222, 225, 'Interior', 'positive'],
#   ['7011', 'Interior', 'светлый зал', '214', '225', 'positive']),
#  ([302, 321, 'Service', 'positive'],
#   ['7011', 'Service', 'отношение', '302', '311', 'positive']),
#  ([302, 321, 'Service', 'positive'],
#   ['7011', 'Service', 'клиенту', '314', '321', 'negative']),
#  ([494, 518, 'Food', 'positive'],
#   ['7011', 'Food', 'говядины', '510', '518', 'positive']),
#  ([520, 549, 'Food', 'positive'],
#   ['7011', 'Food', 'баклажаны', '520', '529', 'positive']),
#  ([520, 549, 'Food', 'positive'],
#   ['7011', 'Food', 'сыром', '544', '549', 'positive']),
#  ([551, 581, 'Food', 'positive'],
#   ['7011', 'Interior', 'тарелки', '574', '581', 'positive']),
#  ([583, 600, 'Food', 'positive'],
#   ['7011', 'Food', 'мясо', '583', '587', 'positive']),
#  ([1060, 1075, 'Interior', 'positive'],
#   ['7011', 'Interior', 'зала', '1071', '1075', 'positive']),
#  ([296, 313, 'Food', 'positive'],
#   ['33043', 'Food', 'десерт', '296', '302', 'positive']),
#  ([561, 575, 'Service', 'positive'],
#   ['33043', 'Service', 'девушка', '561', '568', 'positive']),
#  ([561, 575, 'Service', 'positive'],
#   ['33043', 'Service', 'хостес', '569', '575', 'negative']),
#  ([792, 797, 'Service', 'positive'],
#   ['33043', 'Service', 'заказ принесли', '792', '806', 'positive']),
#  ([323, 336, 'Service', 'positive'],
#   ['20862', 'Food', 'меню', '332', '336', 'positive']),
#  ([464, 480, 'Food', 'neutral'],
#   ['20862', 'Food', 'сок', '477', '480', 'positive']),
#  ([708, 720, 'Food', 'neutral'],
#   ['20862', 'Food', 'Цезарь', '708', '714', 'neutral']),
#  ([708, 720, 'Food', 'neutral'],
#   ['20862', 'Food', 'салат', '715', '720', 'positive']),
#  ([306, 325, 'Food', 'positive'],
#   ['33252', 'Food', 'пиво', '321', '325', 'positive']),
#  ([576, 592, 'Service', 'positive'],
#   ['33252', 'Interior', 'стол', '576', '580', 'positive']),
#  ([576, 592, 'Service', 'positive'],
#   ['33252', 'Service', 'обслуживали', '581', '592', 'positive']),
#  ([633, 659, 'Service', 'positive'],
#   ['33252', 'Food', 'блюда', '633', '638', 'positive']),
#  ([833, 868, 'Interior', 'positive'],
#   ['33252',
#    'Interior',
#    'Развлекательная программа',
#    '833',
#    '858',
#    'positive']),
#  ([833, 868, 'Interior', 'positive'],
#   ['33252', 'Whole', 'ресторана', '859', '868', 'positive']),
#  ([1069, 1086, 'Service', 'positive'],
#   ['33252', 'Service', 'персоналу', '1069', '1078', 'positive']),
#  ([200, 225, 'Food', 'neutral'],
#   ['34956', 'Food', 'котлетки', '200', '208', 'positive']),
#  ([200, 225, 'Food', 'neutral'],
#   ['34956', 'Food', 'пюре', '221', '225', 'both']),
#  ([228, 242, 'Food', 'neutral'],
#   ['34956', 'Food', 'ролл', '238', '242', 'neutral']),
#  ([524, 556, 'Whole', 'negative'],
#   ['34956', 'Food', 'японской кухни', '542', '556', 'positive']),
#  ([524, 556, 'Whole', 'negative'],
#   ['34956', 'Food', 'кухни', '551', '556', 'positive']),
#  ([793, 822, 'Food', 'positive'],
#   ['34956', 'Food', 'котлетки', '793', '801', 'positive']),
#  ([903, 918, 'Food', 'positive'],
#   ['34956', 'Food', 'суп', '903', '906', 'positive']),
#  ([903, 918, 'Food', 'positive'],
#   ['34956', 'Food', 'рыб', '915', '918', 'positive']),
#  ([938, 957, 'Food', 'positive'],
#   ['34956', 'Food', 'пюре', '953', '957', 'both']),
#  ([395, 407, 'Food', 'positive'],
#   ['9289', 'Food', 'мяса', '403', '407', 'positive']),
#  ([74, 92, 'Food', 'neutral'],
#   ['14539', 'Food', 'шашлыки', '74', '81', 'positive']),
#  ([74, 92, 'Food', 'neutral'],
#   ['14539', 'Food', 'свинины', '85', '92', 'positive']),
#  ([132, 147, 'Food', 'neutral'],
#   ['14539', 'Food', 'морсу', '142', '147', 'neutral']),
#  ([173, 191, 'Service', 'neutral'],
#   ['14539', 'Food', 'вина', '187', '191', 'positive']),
#  ([952, 967, 'Service', 'positive'],
#   ['14539', 'Service', 'человек', '960', '967', 'positive']),
#  ([998, 1010, 'Service', 'positive'],
#   ['14539', 'Service', 'заказа', '1004', '1010', 'positive']),
#  ([748, 765, 'Interior', 'negative'],
#   ['15567', 'Food', 'горячие', '748', '755', 'neutral']),
#  ([927, 945, 'Service', 'negative'],
#   ['15567', 'Service', 'работы', '939', '945', 'positive']),
#  ([1095, 1113, 'Service', 'negative'],
#   ['15567', 'Service', 'официантка', '1103', '1113', 'positive']),
#  ([390, 420, 'Food', 'neutral'],
#   ['36926', 'Food', 'салат', '390', '395', 'positive']),
#  ([453, 464, 'Food', 'neutral'],
#   ['36926', 'Food', 'вина', '460', '464', 'positive']),
#  ([567, 580, 'Interior', 'positive'],
#   ['36512', 'Interior', 'зал', '577', '580', 'positive']),
#  ([739, 761, 'Service', 'positive'],
#   ['36512', 'Whole', 'рестораном', '751', '761', 'positive']),
#  ([853, 868, 'Interior', 'positive'],
#   ['36512', 'Interior', 'зала', '864', '868', 'positive']),
#  ([402, 413, 'Food', 'positive'],
#   ['11532', 'Food', 'чай', '402', '405', 'neutral']),
#  ([431, 446, 'Food', 'positive'],
#   ['11532', 'Food', 'цезарь', '431', '437', 'neutral']),
#  ([431, 446, 'Food', 'positive'],
#   ['11532', 'Food', 'тунцом', '440', '446', 'positive']),
#  ([547, 561, 'Food', 'neutral'],
#   ['11532', 'Food', 'сорбет', '555', '561', 'neutral']),
#  ([204, 223, 'Food', 'positive'],
#   ['5155', 'Food', 'баклажан', '215', '223', 'positive']),
#  ([251, 278, 'Food', 'positive'],
#   ['5155', 'Whole', 'базиликом', '269', '278', 'neutral']),
#  ([294, 313, 'Food', 'positive'],
#   ['5155', 'Food', 'суп', '294', '297', 'positive']),
#  ([851, 875, 'Food', 'positive'],
#   ['31004', 'Food', 'салат', '851', '856', 'positive']),
#  ([851, 875, 'Food', 'positive'],
#   ['31004', 'Food', 'овощей', '869', '875', 'positive']),
#  ([212, 225, 'Service', 'positive'],
#   ['2606', 'Food', 'меню', '221', '225', 'positive']),
#  ([261, 272, 'Service', 'positive'],
#   ['2606', 'Service', 'заказ', '267', '272', 'positive']),
#  ([100, 117, 'Food', 'positive'],
#   ['3552', 'Food', 'салаты', '100', '106', 'positive']),
#  ([100, 117, 'Food', 'positive'],
#   ['3552', 'Food', 'закуску', '110', '117', 'positive']),
#  ([127, 145, 'Food', 'positive'],
#   ['3552', 'Food', 'большой выбор', '119', '132', 'positive']),
#  ([127, 145, 'Food', 'positive'],
#   ['3552', 'Food', 'выбор горячих', '127', '140', 'negative']),
#  ([127, 145, 'Food', 'positive'],
#   ['3552', 'Food', 'горячих блюд', '133', '145', 'positive']),
#  ([127, 145, 'Food', 'positive'],
#   ['3552', 'Food', 'блюд', '141', '145', 'positive']),
#  ([185, 208, 'Food', 'positive'],
#   ['3552', 'Food', 'приготовления', '195', '208', 'neutral']),
#  ([252, 275, 'Food', 'positive'],
#   ['3552', 'Food', 'торт', '252', '256', 'positive']),
#  ([252, 275, 'Food', 'positive'],
#   ['3552', 'Food', 'десерт', '269', '275', 'positive']),
#  ([233, 246, 'Food', 'positive'],
#   ['7154', 'Food', 'мясные', '233', '239', 'positive']),
#  ([233, 246, 'Food', 'positive'],
#   ['7154', 'Food', 'салаты', '240', '246', 'positive']),
#  ([253, 265, 'Interior', 'negative'],
#   ['35325', 'Service', 'людей', '260', '265', 'positive']),
#  ([40, 52, 'Interior', 'positive'],
#   ['5974', 'Interior', 'музыка', '46', '52', 'positive']),
#  ([77, 92, 'Food', 'positive'],
#   ['5974', 'Food', 'блюд', '88', '92', 'positive']),
#  ([159, 165, 'Interior', 'positive'],
#   ['19817', 'Interior', 'свободный столик', '149', '165', 'both']),
#  ([344, 358, 'Food', 'neutral'],
#   ['19817', 'Food', 'кухню', '353', '358', 'positive']),
#  ([481, 500, 'Food', 'both'],
#   ['19817', 'Food', 'ассортимента', '481', '493', 'positive']),
#  ([577, 594, 'Food', 'positive'],
#   ['19817', 'Food', 'соки', '590', '594', 'positive']),
#  ([623, 639, 'Food', 'positive'],
#   ['19817', 'Food', 'меню', '635', '639', 'positive']),
#  ([877, 890, 'Service', 'negative'],
#   ['9216', 'Service', 'заказывать', '880', '890', 'neutral']),
#  ([18, 32, 'Whole', 'positive'],
#   ['8996', 'Whole', 'пабе', '18', '22', 'positive']),
#  ([808, 827, 'Whole', 'positive'],
#   ['8996', 'Whole', 'впечатления', '808', '819', 'positive']),
#  ([808, 827, 'Whole', 'positive'],
#   ['8996', 'Whole', 'паба', '823', '827', 'positive']),
#  ([571, 584, 'Service', 'positive'],
#   ['38299', 'Service', 'заказ', '579', '584', 'positive']),
#  ([633, 648, 'Food', 'neutral'],
#   ['38299', 'Food', 'салат', '633', '638', 'positive']),
#  ([741, 766, 'Food', 'neutral'],
#   ['38299', 'Food', 'говядиной', '757', '766', 'positive']),
#  ([769, 780, 'Food', 'neutral'],
#   ['38299', 'Food', 'рибай', '775', '780', 'positive']),
#  ([930, 954, 'Food', 'positive'],
#   ['38299', 'Food', 'овощах', '948', '954', 'positive']),
#  ([981, 991, 'Food', 'positive'],
#   ['38299', 'Food', 'мяса', '987', '991', 'positive']),
#  ([93, 111, 'Whole', 'neutral'],
#   ['37819', 'Whole', 'кафе', '93', '97', 'positive']),
#  ([282, 295, 'Interior', 'positive'],
#   ['37819', 'Interior', 'шоу', '282', '285', 'positive']),
#  ([282, 295, 'Interior', 'positive'],
#   ['37819', 'Interior', 'программа', '286', '295', 'positive']),
#  ([533, 548, 'Food', 'positive'],
#   ['37819', 'Food', 'меню', '544', '548', 'positive']),
#  ([580, 600, 'Service', 'positive'],
#   ['37819', 'Service', 'администратору', '580', '594', 'positive']),
#  ([820, 832, 'Whole', 'neutral'],
#   ['37819', 'Food', 'выбора', '820', '826', 'both']),
#  ([820, 832, 'Whole', 'neutral'],
#   ['37819', 'Whole', 'места', '827', '832', 'positive']),
#  ([55, 69, 'Food', 'positive'],
#   ['11770', 'Food', 'палочки', '62', '69', 'negative']),
#  ([660, 674, 'Food', 'positive'],
#   ['11770', 'Food', 'мясо', '660', '664', 'positive']),
#  ([896, 936, 'Food', 'positive'],
#   ['11770', 'Food', 'блюдо', '896', '901', 'positive'])]

# %% [markdown]
# Accuracy по полностью совпавшим упоминаниям:

# %%
sentiment_accuracy(fully_matched_pairs)
# Out:
# Mention sentiment accuracy: 0.6772300469483568

# %% [markdown]
# Accuracy по частично совпавшим упоминаниям:

# %%
sentiment_accuracy(partially_matched_pairs)
# Out:
# Mention sentiment accuracy: 0.6370967741935484

# %% [markdown]
# # Оценка 3: accuracy по тональности категории

# %%
gold_test_cats_path = "dev_cats.txt"
pred_test_cats_path = "dev_pred_cats.txt"

# %%
with open(gold_test_cats_path) as gc, open(pred_test_cats_path) as pc:
    gold_labels = set(gc.readlines())
    pred_labels = set(pc.readlines())
    print(
        "Overall sentiment accuracy:",
        len(gold_labels & pred_labels) / len(gold_labels)
    )
# Out:
# Overall sentiment accuracy: 0.523943661971831
